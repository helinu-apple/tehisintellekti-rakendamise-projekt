# %%
import pandas as pd
data = pd.read_csv("tehisintellekti-rakendamise-projekt/andmed/toorandmed.csv")

# %%
data.head()
# Out:
#                             course_uuid         code  \
# 0  eefb3a8d-7669-a5dc-9e13-6f95d719ebdf  LOMR.03.021
# 1  76162416-d608-f48f-ec5d-5c40ce9b320d  FLFI.00.016
# 2  fdffd50c-3d1b-3517-aaef-c0ea70fa85e0  FLGR.01.138
# 3  9c7f4c4c-f4a5-4a5d-533e-7a85e99babcf  LOKT.00.009
# 4  b9d5b558-bf74-62fc-bfd8-43618a81341d  LOKT.04.003
#
#                                        title__en  \
# 0  Practical Course of Microbiology and Virology
# 1                               Doctoral Seminar
# 2          History of English-Speaking Countries
# 3                              Medical Chemistry
# 4                Colloid and Surface Chemistry I
#
#                               version__title__en  credits  \
# 0  Practical Course of Microbiology and Virology      6.0
# 1                               Doctoral Seminar     15.0
# 2          History of English-Speaking Countries      6.0
# 3                              Medical Chemistry      5.0
# ...

# %%
data.count()
# Out:
# course_uuid                            3031
# code                                   3031
# title__en                              3031
# version__title__en                     3019
# credits                                3031
#                                        ...
# overview__description__de                 2
# title__vro                                2
# overview__description__vro                2
# version__title__vro                       2
# version__overview__description__vro       2
# Length: 223, dtype: int64

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
data[data['code'] == 'LTFY.02.002']
# Out:
#                                course_uuid         code  \
# 1737  d70ab9dd-28f4-3241-0e68-812c10c83b39  LTFY.02.002
#
#                                   title__en  \
# 1737  Classes and Technologies of Materials
#
#                          version__title__en  credits  \
# 1737  Classes and Technologies of Materials     12.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                   overview__description__en  \
# ...

# %%
pd.set_option('display.max_rows', None)

data.loc[data['code'] == 'LTFY.02.002'].iloc[0].to_frame()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
print(data. dtypes)
# Out:
# course_uuid                                                                    object
# code                                                                           object
# title__en                                                                      object
# version__title__en                                                             object
# credits                                                                       float64
# overview__description__en                                                      object
# version__overview__description__en                                             object
# overview__learning_outcomes_text_en                                            object
# uuid                                                                           object
# state__code                                                                    object
# state__et                                                                      object
# ...

# %%
data.dtypes.value_counts()
# Out:
# object     194
# float64     23
# bool         5
# int64        1
# Name: count, dtype: int64

# %%
column_nan_count = data.iloc[0].isnull().sum()

# %%
print("NaN count per column:")
print(column_nan_count)
# Out:
# NaN count per column:
# 91
